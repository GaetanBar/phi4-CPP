# %%
from mps_toolkit.circuit import build_circuit
from overlap import state_overlap

# %%
import matplotlib.pyplot as plt
import math
import numpy as np
# %matplotlib inline
# ============================================================
# 1. SCALE FACTOR
# ============================================================

def scale_factor(t, a_i=1.0, a_f=2.0, rho=2.0, t0=1.0):
    """
    Cosmological scale factor a(t).

    Replace this example with the desired cosmology.
    """
    return a_i + 0.5*(a_f-a_i)*(1 + np.tanh(rho*(t-t0)))


# ============================================================
# 2. TIME-DEPENDENT COUPLINGS
# ============================================================

def couplings(t, mass, lam=0.0):
    """
    For the canonical FLRW Hamiltonian

        H(t) =
            J1(t) * sum_j pi_j^2
          + J2(t) * sum_j phi_j^2
          + J3(t) * sum_j (phi_{j+1} - phi_j)^2
          + J4(t) * sum_j phi_j^4

    In 1+1 dimensions:

        J1 = 1 / (2 a)
        J2 = a m^2 / 2
        J3 = 1 / (2 a)
        J4 = a lambda / 4!
    """

    a = scale_factor(t)

    J1 = 1.0 / (2.0*a)
    J2 = 0.5 * a * mass**2
    J3 = 1.0 / (2.0*a)
    J4 = a * lam / 24.0  #stays 0 if lambda_ini=0#

    return J1, J2, J3, J4


# ============================================================
# 3. YOUR EXISTING EVOLUTION BLOCKS
# ============================================================
#
# Keep your definitions exactly as you already have them:
#
#     Upi_wall(qc, nq, J1, tau)
#
#     Uphi_wall(qc, nq, J2, J3, J4, tau)
#
# The important point is that J1, J2, J3, J4 are now
# recomputed at each time step.
# ============================================================

def Upi_wall(qc, nq, J1, tau): # Upi_wall = sum_j Upi_j (require quantum fourier transform)
    from qiskit.circuit.library import QFTGate
    # Upi_j = exp( -i (tau J1 pi^2 / (4 delta_phi^2) ) Z_{2j} Z_{2j+1} )
    # RZZ(theta) = exp( -i (theta / 2) Z_i Z_j)
    theta = 2*tau*J1*np.pi**2 / (4*delta_phi**2)
    for j in range(L):
        qc.compose(QFTGate(2), qubits=[2*j, 2*j+1], inplace=True)
        qc.rzz(theta,2*j,2*j+1)
        qc.compose(QFTGate(2).inverse(), qubits=[2*j, 2*j+1], inplace=True)

def Uphi_wall(qc, nq, J2, J3, J4, tau): # Uphi_wall = sum_j Uphi_j
    # Uphi_j has 6 terms, Uphi_j = exp(- i tau [
    # Z_{2j}   Z_{2j+1} (J2 ( 4 phi_max^2 / 9) + J3 (4 phi_max^2 / 9) + J4 (40 phi_max^4 / 81) ) +  --> 0q between
    # Z_{2j+1} Z_{2j+2} (J3 (-4 phi_max^2 / 9) ) +   --> 0q between
    # Z_{2j+2} Z_{2j+3} (J3 ( 4 phi_max^2 / 9) ) +   --> 0q between
    # Z_{2j}   Z_{2j+2} (J3 (-8 phi_max^2 / 9) ) +   --> 1q between
    # Z_{2j+1} Z_{2j+3} (J3 (-2 phi_max^2 / 9) ) +   --> 1q between
    # Z_{2j}   Z_{2j+3} (J3 (-4 phi_max^2 / 9) ) ] ) --> 2q between
    # RZZ(theta) = exp( -i (theta / 2) Z_i Z_j)
    
    # 1. qubits next to each other
    theta1 = 2*tau*(J2*( 4*phi_max**2 / 9) + J3*(4*phi_max**2 / 9) + J4*(40*phi_max**4 / 81))
    theta2 = 2*tau*J3*(-4*phi_max**2 / 9)
    theta3 = 2*tau*J3*( 4*phi_max**2 / 9)
    def theta_even_odd(j):
        theta = 0
        if j%2==0:
            theta += theta1
        else:
            theta += theta2
        if j%2==0 and j>=2:
            theta += theta3
        return theta
    for j in range(0, nq-1, 2):
        qc.rzz(theta_even_odd(j), j, j+1)
    for j in range(1, nq-1, 2):
        qc.rzz(theta_even_odd(j), j, j+1)
    
    # 2. qubits with 1 site between them
    theta_even = 2*tau*J3*(-8)*phi_max**2 / 9
    theta_odd  = 2*tau*J3*(-2)*phi_max**2 / 9
    def theta_even_odd(j):
        if j%2==0:
            return theta_even
        else:
            return theta_odd
    for j in range(0,nq-2,3):
        qc.rzz(theta_even_odd(j), j, j+2)
    for j in range(1,nq-2,3):
        qc.rzz(theta_even_odd(j), j, j+2)
    for j in range(2,nq-2,3):
        qc.rzz(theta_even_odd(j), j, j+2)
    
    # 3. qubits with 2 sites between them
    theta = 2*tau*J3*(-4)*phi_max**2 / 9
    for j in range(0, nq-3, 4):
        qc.rzz(theta, j, j+3)
    for j in range(2, nq-3, 4):
        qc.rzz(theta, j, j+3)

    
# ============================================================
# 4. FIRST-ORDER TIME-DEPENDENT TROTTER STEP
# ============================================================

def trotter_step_1st(qc, nq, t, dt, mass, lam=0.0):
    """
    One first-order Trotter step for the time-dependent H(t).

    Midpoint prescription:

        H_n = H(t + dt/2)

    and

        U_n ~ Upi(dt) Uphi(dt)

    The ordering can also be reversed, but it must be used
    consistently.
    """

    # Evaluate time-dependent Hamiltonian at midpoint
    t_mid = t + 0.5*dt

    J1, J2, J3, J4 = couplings(
        t_mid,
        mass=mass,
        lam=lam
    )

    # Momentum evolution
    Upi_wall(
        qc,
        nq=nq,
        J1=J1,
        tau=dt
    )

    # Field / potential / gradient evolution
    Uphi_wall(
        qc,
        nq=nq,
        J2=J2,
        J3=J3,
        J4=J4,
        tau=dt
    )


# ============================================================
# 5. SECOND-ORDER TIME-DEPENDENT TROTTER STEP
# ============================================================

def trotter_step_2nd(qc, nq, t, dt, mass, lam=0.0):
    """
    One second-order (Strang) Trotter step:

        U_n ~
            Upi(dt/2)
            Uphi(dt)
            Upi(dt/2)

    with all couplings evaluated at the temporal midpoint

        t_mid = t + dt/2.
    """

    t_mid = t + 0.5*dt

    J1, J2, J3, J4 = couplings(
        t_mid,
        mass=mass,
        lam=lam
    )

    # ----------------------------------------
    # Half field evolution
    # ----------------------------------------

    Upi_wall(
        qc,
        nq=nq,
        J1=J1,
        tau=0.5*dt
    )

    # ----------------------------------------
    # Full momentum evolution
    # ----------------------------------------

    
    Uphi_wall(
        qc,
        nq=nq,
        J2=J2,
        J3=J3,
        J4=J4,
        tau=dt
    )

    # ----------------------------------------
    # Half field evolution
    # ----------------------------------------

    Upi_wall(
        qc,
        nq=nq,
        J1=J1,
        tau=0.5*dt
    )


# ============================================================
# 6. FULL TIME EVOLUTION
# ============================================================

def time_evolve(
    qc,
    nq,
    t_initial,
    t_final,
    n_steps,
    mass,
    lam=0.0,
    trotter_order=1
):
    """
    Build the complete time-dependent Trotter circuit

        U(t_final, t_initial)
          = T exp[-i integral H(t) dt]

    using either first- or second-order Trotterization.
    """

    dt = (t_final - t_initial) / n_steps

    for n in range(n_steps):

        t_n = t_initial + n*dt

        if trotter_order == 1:

            trotter_step_1st(
                qc,
                nq=nq,
                t=t_n,
                dt=dt,
                mass=mass,
                lam=lam
            )

        elif trotter_order == 2:

            trotter_step_2nd(
                qc,
                nq=nq,
                t=t_n,
                dt=dt,
                mass=mass,
                lam=lam
            )

        else:
            raise ValueError(
                "trotter_order must be 1 or 2"
            )

    return qc

# %%
# parameters\
k=None
L         = 10
nq        = 2*L
ini       = '01'*L
dt        = 0.1
n_steps   = 20
t_final   = n_steps*dt
mass      = 1.
phi_max   = 1.5
delta_phi = 2*phi_max/3

# %%
def circuit_instantaneous_vacuum(t, L):
    m_t = np.sqrt(scale_factor(t))*mass
    circ_vac_t=build_circuit(L, mass, k)
    return circ_vac_t

# %%
ini = build_circuit(L, mass, k)
Cpp=[]
T_f = np.linspace(0.01,1.,50)
for tf in T_f:
    evo = time_evolve(ini,
    nq=nq,
    t_initial=0,
    t_final=tf,
    n_steps=10,
    mass=mass,
    lam=0.0,
    trotter_order=1)
    Cpp.append(abs(state_overlap(evo , circuit_instantaneous_vacuum(tf, L)))**2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.local/lib/python3.14/site-packages/numba/core/serialize.py:30, in _numba_unpickle(address, bytedata, hashed)
#      27 _unpickled_memo = {}
# ---> 30 def _numba_unpickle(address, bytedata, hashed):
#      31     """Used by `numba_unpickle` from _helperlib.c
#      32
#      33     Parameters
#    (...)     42         unpickled object
#      43     """
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <function _numba_unpickle at 0x7fb90e50bab0> returned a result with an exception set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 ini = build_circuit(L, mass, k)
#       2 Cpp=[]
#       3 T_f = np.linspace(0.01,1.,50)
#
# File ~/Documents/Academic/Quantum Simulations/CPP/phi4-CPP/gaetan/mps_toolkit/circuit.py:102, in build_circuit(L, m, k, phi_max, backend, chi_ref, name)
#      99 """QuantumCircuit on 2L qubits preparing the vacuum, one parallel staircase
#     100 per segment. Same arguments as evaluate(), which predicts its fidelity."""
#     101 _require_qiskit()
# --> 102 ts_ref, _ = vacuum_mps(L, m, phi_max, backend, chi_ref)
#     103 cuts = _cut_positions(L, k)
#     104 ts = _truncate(ts_ref, cuts, chi_inner=_CHI)
#
# File ~/Documents/Academic/Quantum Simulations/CPP/phi4-CPP/gaetan/mps_toolkit/core.py:156, in vacuum_mps(L, m, phi_max, backend, chi_ref)
#     154     return _vacuum_exact(L, m, phi_max)
#     155 if backend == "dmrg":
# --> 156     return _vacuum_dmrg(L, m, phi_max, chi_ref)
#     157 raise ValueError(f"unknown backend {backend!r}")
#
# File ~/Documents/Academic/Quantum Simulations/CPP/phi4-CPP/gaetan/mps_toolkit/core.py:144, in _vacuum_dmrg(L, m, phi_max, chi_ref)
#     142 mpo = _build_mpo(L, m, phi_max)
#     143 dmrg = qtn.DMRG2(mpo, bond_dims=[4, 8, 16, chi_ref], cutoffs=1e-12)
# --> 144 dmrg.solve(tol=1e-10, verbosity=0)
#     145 return _split_sites_to_qubits(_quimb_to_list(dmrg.state)), float(np.real(dmrg.energy))
#
# File ~/.local/lib/python3.14/site-packages/quimb/tensor/tn1d/dmrg.py:1127, in DMRG.solve(self, tol, bond_dims, cutoffs, sweep_sequence, max_sweeps, verbosity, suppress_warnings)
#    1125     with warnings.catch_warnings():
#    1126         warnings.simplefilter("ignore")
# -> 1127         energy = self.sweep(direction=direction, **sweep_opts)
#    1128 else:
#    1129     energy = self.sweep(direction=direction, **sweep_opts)
#
# File ~/.local/lib/python3.14/site-packages/quimb/tensor/tn1d/dmrg.py:966, in DMRG.sweep(self, direction, canonize, verbosity, **update_opts)
#     961 self.ME_eff_ham = MovingEnvironment(self.TN_energy, **en_opts)
#     963 # perform the sweep, collecting local and total energies
#     964 local_ens, tot_ens = zip(
#     965     *[
# --> 966         self._update_local_state(i, direction=direction, **update_opts)
#     967         for i in sweep
#     968     ]
#     969 )
#     971 if verbosity:
#     972     sweep.close()
#
# File ~/.local/lib/python3.14/site-packages/quimb/tensor/tn1d/dmrg.py:880, in DMRG._update_local_state(self, i, **update_opts)
#     876     self.ME_eff_norm.move_to(i)
#     878 self.ME_eff_ham.move_to(i)
# --> 880 return {
#     881     1: self._update_local_state_1site,
#     882     2: self._update_local_state_2site,
#     883 }[self.bsz](i, **update_opts)
#
# File ~/.local/lib/python3.14/site-packages/quimb/tensor/tn1d/dmrg.py:842, in DMRG._update_local_state_2site(self, i, direction, **compress_opts)
#     840 # split the two site local groundstate
#     841 T_AB = Tensor(loc_gs.toarray().reshape(dims), uix)
# --> 842 L, R = T_AB.split(
#     843     left_inds=uix_L,
#     844     get="arrays",
#     845     absorb=direction,
#     846     right_inds=uix_R,
#     847     **compress_opts,
#     848 )
#     850 # insert back into state and all tensor networks viewing it
#     851 self._k[i].modify(data=L, inds=(*uix_L, u_bond_ind))
#
# File ~/.local/lib/python3.14/site-packages/quimb/tensor/tensor_core.py:3046, in Tensor.split(self, *args, **kwargs)
#    3044 @functools.wraps(tensor_split)
#    3045 def split(self, *args, **kwargs):
# -> 3046     return tensor_split(self, *args, **kwargs)
#
# File ~/.local/lib/python3.14/site-packages/quimb/tensor/tensor_core.py:588, in tensor_split(T, left_inds, method, absorb, max_bond, cutoff, cutoff_mode, renorm, get, ltags, rtags, stags, bond_ind, right_inds, matrix_svals, info, **kwargs)
#     585     return s
#     587 # do the matrix decomposition!
# --> 588 left, s, right = array_split(
#     589     array,
#     590     method=method,
#     591     absorb=absorb,
#     592     max_bond=max_bond,
#     593     cutoff=cutoff,
#     594     cutoff_mode=cutoff_mode,
#     595     renorm=renorm,
#     596     info=info,
#     597     **kwargs,
#     598 )
#     599 # note `s` itself will be None unless `absorb=None` is specified
#     601 if nleft != 1 and left is not None:
#     602     # unfuse dangling left indices
#
# File ~/.local/lib/python3.14/site-packages/quimb/tensor/decomp.py:173, in array_split(x, method, absorb, max_bond, cutoff, cutoff_mode, renorm, info, **kwargs)
#     170 if method in _DENSE_ONLY_METHODS and isinstance(x, spla.LinearOperator):
#     171     x = x.to_dense()
# --> 173 return _SPLIT_FNS[method](x, **split_opts, **kwargs)
#
# File ~/.local/lib/python3.14/site-packages/autoray/autoray.py:1500, in Composed.__call__(self, like, *args, **kwargs)
#    1498 # `get_lib_fn` will call `make_function` if the function doesn't exist
#    1499 fn = get_lib_fn(backend, self._name)
# -> 1500 return fn(*args, **kwargs)
#
# File ~/.local/lib/python3.14/site-packages/quimb/tensor/decomp.py:1018, in svd_truncated_numpy(x, cutoff, cutoff_mode, max_bond, absorb, renorm, info)
#    1015 calc_error = "error" in info
#    1017 try:
# -> 1018     U, s, VH, error = svd_truncated_numba(
#    1019         x,
#    1020         cutoff,
#    1021         cutoff_mode,
#    1022         max_bond,
#    1023         absorb,
#    1024         renorm,
#    1025         calc_error=calc_error,
#    1026     )
#    1027 except ValueError as e:  # pragma: no cover
#    1028     warnings.warn(f"Got: {e}, falling back to scipy gesvd driver.")
#
# SystemError: CPUDispatcher(<function svd_truncated_numba at 0x7fb90d15afb0>) returned a result with an exception set

# %%
survie=  [[1-l] for l in Cpp]

# %%
plt.plot(T_f,survie)
plt.grid('True')
